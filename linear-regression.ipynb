# %% [markdown]
# # Machine Learning
# ### - Supervised Machine Learning  ( data + labels)
#             - Regression    ( Regression, Lasso, Ridge)
#                     - Simple Linear Regression
#                     - Multiple Linear Regression
#                     - Polynomial Regression
#
#              - Classification
#                     - Binary Classification (0,1)(T/F)(CAT/DOG)
#                     - Multiclassification   (Morethan 2 classes)
# ### - Unsupervised Machine Learning  ( data )
#                     - Clustering
#                     - Dimensionality Reduction
#
# ### - Semi_Supervised Machine Learning (data + labels(autoencoded) )
# ### - Reiforcement Learning

# %% [markdown]
# # **$$simple-linear-regression$$**

# %% [markdown]
# # **Step 1--Data Preprocessing**

# %%
#Importing libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# reading data
data  =  pd.read_csv(r"D:\py\PY project\machine learning\class-files\class2 linearregression\weight-height.csv")

# %%
# view data
data.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
# checking null values
data.isnull().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# dtype: int64

# %%
# checking shape of data
data.shape
# Out:
# (10000, 3)

# %% [markdown]
# ## Now checking the corelation between the each varible  (genger is categorical variable we will not count it in linear regression)

# %%
x = data["Height"]
y = data["Weight"]

# %%
plt.scatter(x,y,label='Height',color='Orange',s=50)
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Height vs Weight')
plt.legend(loc="lower right")
plt.show()

# %%
# Calculate correlation between height and weight
correlation = x.corr(y)
print(f"Correlation between height and weight: {correlation}")
# Out:
# Correlation between height and weight: 0.9247562987378063

# %% [markdown]
# # **Step 2-Splitting the dataset into training and testing set**

# %%
#Creating linear regression model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1321)
#  train-test-split will break my dataset into four parts 2 sets for trainning (80%) and 2 sets for testing (20%)

# %% [markdown]
# # **Step 3-Build a linear model**

# %% [markdown]
#  ### Training the model with the help of x-train and y-tain

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Prediction on Training Data : Training Accuracy

# %%
y_train_pred = regressor.predict(X_train)

# %%
pd.DataFrame({'Original Weight':y_train, 'Predicted_Weight': y_train_pred})
# Out:
#       Original Weight  Predicted_Weight
# 592        172.794261        171.947181
# 8888       147.029164        136.865319
# 726        226.701023        223.526217
# 5607       161.431658        153.409738
# 6081       149.599596        152.788998
# ...               ...               ...
# 824        178.918714        193.225172
# 6561       131.395557        145.067915
# 7916       122.924680        125.777442
# 7018       141.375098        132.066580
# 3266       212.256253        215.409227
#
# [8000 rows x 2 columns]

# %%
plt.scatter(range(len(y_train)), y_train, color='blue', label='Actual Weight', s=10)
plt.scatter(range(len(y_train_pred)), y_train_pred, color='red', label='Predicted Weight', s=10)
plt.xlabel('Index')
plt.ylabel('Weight')
plt.title('Actual vs Predicted Weight on train data')
plt.legend()
plt.show()

# %% [markdown]
# ## finding the best line on y-train-prediction

# %%
# Visualising the Training set results
plt.scatter(X_train, y_train, color = 'skyblue')
plt.plot(X_train, y_train_pred, color = 'red')
plt.title('Hight vs Weights (Training set)')
plt.xlabel('Hight')
plt.ylabel('Weight')
plt.show()

# %%
print('Coefficients: ', regressor.coef_)
print("Intercept", regressor.intercept_)
# Out:
# Coefficients:  [7.73190342]
# Intercept -351.7907050748323

# %%
print('Variance score: %.2f' % regressor.score(X_train, y_train))
# Out:
# Variance score: 0.85

# %% [markdown]
# # Prediction on Testing Data : Testing Accuracy

# %%
y_test_pred = regressor.predict(X_test)

# %%
pd.DataFrame({'Original Weight':y_test, 'Predicted_Weight': y_test_pred})
# Out:
#       Original Weight  Predicted_Weight
# 2433       183.936860        184.603609
# 8943       129.001462        137.582434
# 354        170.191325        169.409373
# 164        193.217673        168.284992
# 1745       166.390656        169.774674
# ...               ...               ...
# 1707       180.793711        151.553391
# 4047       192.092449        182.016215
# 7984       128.091026        136.653387
# 272        214.060148        198.983018
# 5550       112.436342        118.369119
#
# [2000 rows x 2 columns]

# %%
plt.scatter(range(len(y_test)), y_test, color='green', label='Actual Weight', s=10)
plt.scatter(range(len(y_test_pred)), y_test_pred, color='red', label='Predicted Weight', s=10)
plt.xlabel('Index')
plt.ylabel('Weight')
plt.title('Actual vs Predicted Weight on test data')
plt.legend()
plt.show()

# %% [markdown]
# ## finding the best line on y-test-prediction

# %%
# Visualising the Training set results
plt.scatter(X_test, y_test, color = "Yellow")
plt.plot(X_test, y_test_pred, color = 'gree')
plt.title('Hight vs Weights (Test data)')
plt.xlabel('Hight')
plt.ylabel('Weight')
plt.show()

# %%
print('Variance score: %.2f' % regressor.score(X_train, y_train))
# Out:
# Variance score: 0.85
